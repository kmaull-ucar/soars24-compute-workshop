# %%
import requests

r = requests.get("https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2021-01-01&endtime=2024-01-01&minmagnitude=7")

data = r.json()

# %%
import folium
map_eq = folium.Map(location=[37.733795, -122.446747], zoom_start=2)

# %%
for f in data['features']:
    place = f['properties']['place']
    magnitude = f['properties']['mag']
    lat, lon, z = f['geometry']['coordinates']

    # place the data on the map!
    folium.Marker([lon, lat], popup='place:{}\nmagnitude:{}'.format(place, magnitude)).add_to(map_eq)
map_eq
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ace765ed19defe5d70c0ae3715e1d41 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ace765ed19defe5d70c0ae3715e1d41&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ace765ed19defe5d70c0ae3715e1d41 = L.map(
#                 &quot;map_5ace765ed19defe5d70c0ae3715e1d41&quot;,
#                 {
#                     center: [37.733795, -122.446747],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e74f5b73418c80e569729ab2dd76e5c1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5ace765ed19defe5d70c0ae3715e1d41);
#
#
#             var marker_a85d9eaa4fc2f03c6f798e769b545adf = L.marker(
#                 [-0.7985, 98.5237],
#                 {}
#             ).addTo(map_5ace765ed19defe5d70c0ae3715e1d41);
#
#
#         var popup_c951b901f89b99fe7fe98f8361509e78 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_833d7b619d4053de6c6a25909c64a7c9 = $(`&lt;div id=&quot;html_833d7b619d4053de6c6a25909c64a7c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;place:None magnitude:7.1&lt;/div&gt;`)[0];
#                 popup_c951b901f89b99fe7fe98f8361509e78.setContent(html_833d7b619d4053de6c6a25909c64a7c9);
#
#
#
#         marker_a85d9eaa4fc2f03c6f798e769b545adf.bindPopup(popup_c951b901f89b99fe7fe98f8361509e78)
#         ;
#
#
#
#
#             var marker_1f6c7384f3117a9988edee2472bd6f22 = L.marker(
#                 [-29.9676, -177.8264],
#                 {}
#             ).addTo(map_5ace765ed19defe5d70c0ae3715e1d41);
#
#
#         var popup_eae845429d43b0468b20afb3f1b831ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9d07282f0454773d636a0578958a904 = $(`&lt;div id=&quot;html_e9d07282f0454773d636a0578958a904&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;place:Kermadec Islands, New Zealand magnitude:7.1&lt;/div&gt;`)[0];
#                 popup_eae845429d43b0468b20afb3f1b831ee.setContent(html_e9d07282f0454773d636a0578958a904);
#
#
#
#         marker_1f6c7384f3117a9988edee2472bd6f22.bindPopup(popup_eae845429d43b0468b20afb3f1b831ee)
#         ;
#
#
#
#
#             var marker_25f73e847227ad99b8eddc31168893c0 = L.marker(
#                 [-6.0255, 112.0332],
#                 {}
#             ).addTo(map_5ace765ed19defe5d70c0ae3715e1d41);
#
#
#         var popup_914c1bf5c891764e0a7a028fecdf9101 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f8c5e461b8e3776d2eda1d44cd1db4f0 = $(`&lt;div id=&quot;html_f8c5e461b8e3776d2eda1d44cd1db4f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;place:96 km N of Tuban, Indonesia magnitude:7&lt;/div&gt;`)[0];
#                 popup_914c1bf5c891764e0a7a028fecdf9101.setContent(html_f8c5e461b8e3776d2eda1d44cd1db4f0);
#
#
#
#         marker_25f73e847227ad99b8eddc31168893c0.bindPopup(popup_914c1bf5c891764e0a7a028fecdf9101)
#         ;
#
#
#
#
#             var marker_77d8959e1774f9c2bffa9d19a3de7784 = L.marker(
#                 [-4.3254, 143.1592],
#                 {}
#             ).addTo(map_5ace765ed19defe5d70c0ae3715e1d41);
#
#
#         var popup_9edd106967217ea1e5a6e95239ae1906 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_faa98581d9a142c0ce09e3eab95ab827 = $(`&lt;div id=&quot;html_faa98581d9a142c0ce09e3eab95ab827&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;place:New Guinea, Papua New Guinea magnitude:7&lt;/div&gt;`)[0];
#                 popup_9edd106967217ea1e5a6e95239ae1906.setContent(html_faa98581d9a142c0ce09e3eab95ab827);
#
#
#
#         marker_77d8959e1774f9c2bffa9d19a3de7784.bindPopup(popup_9edd106967217ea1e5a6e95239ae1906)
#         ;
#
#
#
#
#             var marker_2eaa5ea78b02d44e2fc9cfaac1a54ff9 = L.marker(
#                 [-30.1741, -176.2047],
#                 {}
#             ).addTo(map_5ace765ed19defe5d70c0ae3715e1d41);
#
#
#         var popup_c844e04938c76998b1c846731fe07dfc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9e3fbda0cc4dfcf632963487acfeecf2 = $(`&lt;div id=&quot;html_9e3fbda0cc4dfcf632963487acfeecf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;place:Kermadec Islands region magnitude:7&lt;/div&gt;`)[0];
#                 popup_c844e04938c76998b1c846731fe07dfc.setContent(html_9e3fbda0cc4dfcf632963487acfeecf2);
#
#
#
#         marker_2eaa5ea78b02d44e2fc9cfaac1a54ff9.bindPopup(popup_c844e04938c76998b1c846731fe07dfc)
#         ;
